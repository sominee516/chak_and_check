# %%
# 베스트셀러 전체와 비교 가능
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
bestloan = pd.read_excel('BestLoanList_전체_전체_전국.xlsx')
bestloan = bestloan.head(100)
bestloan
# Out:
#      순위                                서명                     저자  \
# 0     1             달러구트 꿈 백화점 :이미예 장편소설                지은이: 이미예
# 1     2                    아몬드 :손원평 장편소설                지은이: 손원평
# 2     3                 완전한 행복 :정유정 장편소설                지은이: 정유정
# 3     4                           시선으로부터,              정세랑 (지은이)
# 4     5                    (추리 천재) 엉덩이 탐정        트롤 글·그림 ;김정화 옮김
# ..  ...                               ...                    ...
# 95   95  부의 시나리오 :불확실성을 기회로 만드는 4가지 투자전략                  오건영 지음
# 96   97                          놓지 마 과학!          글·그림: 신태훈,나승훈
# 97   98        돌이킬 수 없는 약속 :야쿠마루 가쿠 장편소설   저자: 야쿠마루 가쿠 ;옮긴이: 김성미
# 98   99                마법천자문 :손오공의 한자 대탐험        저자: 스튜디오시리얼,홍거북
# 99  100   Go go 카카오 프렌즈 :세계 역사 문화 체험 학습만화        글: 김미영 ;그림: 김정한
#
#                  출판사       출판년도     권           ISBN  ISBN부가기호    KDC   대출건수  \
# 0              팩토리나인       2020   NaN  9791165341909    3810.0  813.7  8,473
# 1                 창비       2017   NaN  9788936434267    3810.0  813.7  6,895
# 2               은행나무       2021   NaN  9791167370280    3810.0  813.7  6,610
# 3               문학동네       2020   NaN  9788954672214       NaN  813.7  6,135
# 4                미래엔  2016-2020   9.0  9791164134090   74830.0  833.6  6,074
# ..               ...        ...   ...            ...       ...    ...    ...
# 95     Page2(페이지2북스)       2021   NaN  9791190977265    3320.0  327.8  3,570
# 96      위즈덤하우스 미디어그룹  2016-2020   4.0  9788960863545   67400.0  408.0  3,564
# 97  Book plaza(북플라자)       2017   NaN  9788998274795    3830.0  833.6  3,559
# 98               아울북  2005-2021  46.0  9788950982898   77720.0  711.4  3,548
# 99              북이십일       2018   9.0  9788950982188   74900.0  980.2  3,543
#
#       분야
# 0     소설
# 1     소설
# 2     소설
# 3     소설
# 4     아동
# ..   ...
# 95  경제경영
# 96    아동
# 97    소설
# 98    아동
# 99    아동
#
# [100 rows x 11 columns]

# %% [raw]
# bestseller.columns=['순위','ISBN','도서명','여','남','1위 연령대','2위 연령대','저자','출판사','분야']
# bestseller.여 = bestseller.여.str.split('%').str.get(0)
# bestseller.남 = bestseller.남.str.split('%').str.get(0)
# bestseller['여'] = bestseller['여'].fillna(0)
# bestseller['1위 연령대'] = bestseller['1위 연령대'].fillna(0)
# bestseller['남'] = bestseller['남'].fillna(0)
# bestseller['2위 연령대'] = bestseller['2위 연령대'].fillna(0)
# bestseller.여 = bestseller.여.astype('int')
# bestseller.남 = bestseller.남.astype('int')

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(20,10))
plt.title('베스트셀러내 인기 분야')
sns.countplot(x='분야',data=bestloan)
# Out:
# <AxesSubplot:title={'center':'베스트셀러내 인기 분야'}, xlabel='분야', ylabel='count'>
