# %%
# 시도별 인기 대출 분야 비교하기

# 부산 인기 대출 목록
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
import warnings
warnings.filterwarnings('ignore')
busanbest = pd.read_excel('BestLoanList_전체_전체_부산.xlsx')
busanbest = busanbest
busanbest
# Out:
#       순위                                               서명  \
# 0      1                                      욕 좀 하는 이유나
# 1      2                                   아몬드 :손원평 장편소설
# 2      3    오늘의 법정을 열겠습니다 :시민력을 키우는 허승 판사의 법 이야기, 세상 이야기
# 3      4        우리가 인생이라 부르는 것들 :자기 삶의 언어를 찾는 열네 번의 시 강의
# 4      5                            달러구트 꿈 백화점 :이미예 장편소설
# ..   ...                                              ...
# 195  196  월급쟁이 부자로 은퇴하라 :3년 만에 30년 치 연봉을 번 김 과장의 시스템 마련법
# 196  196      비밀요원 레너드 7 : 인어의 비밀을 찾아라! - 브라운앤프렌즈 미스터리 동화
# 197  196                  (오은영의) 화해 :상처받은 내면의 나와 마주하는 용기
# 198  196                           십 년 가게 5 - 한가할 때도 있습니다
# 199  200                                        그리스 로마 신화
#
#                                          저자           출판사  출판년도    권  \
# 0                             류재향 글 ;이덕화 그림  위즈덤하우스 미디어그룹  2019  NaN
# 1                                  지은이: 손원평            창비  2017  NaN
# 2                                     허승 지음           지학사  2020  NaN
# 3                                    정재찬 지음         인플루엔셜  2020  NaN
# 4                                  지은이: 이미예         팩토리나인  2020  NaN
# ..                                      ...           ...   ...  ...
# 195                                  너나위 지음  RHK(알에이치코리아)  2019  NaN
# 196                     박설연 (지은이), 김덕영 (그림)           아울북  2021  7.0
# 197                                  오은영 지음            대성  2019  NaN
# 198  히로시마 레이코 (지은이), 사다케 미호 (그림), 이소담 (옮긴이)        위즈덤하우스  2021  5.0
# 199                         글: 박시연 ;그림: 최우빈          북이십일  2017  1.0
#
#               ISBN  ISBN부가기호       KDC  대출건수
# 0    9788962472066   74810.0  813.7000   699
# 1    9788936434267    3810.0  813.7000   588
# 2    9791189799212    3360.0  360.0000   517
# 3    9791189995539    3810.0  811.6209   513
# 4    9791165341909    3810.0  813.7000   484
# ..             ...       ...       ...   ...
# 195  9788925566511    3320.0  327.8700   205
# 196  9788950993559       NaN  813.8000   205
# 197  9788997396870    3180.0  189.2000   205
# 198  9791191766103       NaN       NaN   205
# 199  9788950971366   74800.0  219.0000   204
#
# [200 rows x 10 columns]

# %%
# 사용할 컬럼만 들고오기
busanbest = busanbest.loc[:,['순위','서명','KDC','대출건수']]
busanbest
# Out:
#       순위                                               서명       KDC  대출건수
# 0      1                                      욕 좀 하는 이유나   813.7000   699
# 1      2                                   아몬드 :손원평 장편소설   813.7000   588
# 2      3    오늘의 법정을 열겠습니다 :시민력을 키우는 허승 판사의 법 이야기, 세상 이야기   360.0000   517
# 3      4        우리가 인생이라 부르는 것들 :자기 삶의 언어를 찾는 열네 번의 시 강의   811.6209   513
# 4      5                            달러구트 꿈 백화점 :이미예 장편소설   813.7000   484
# ..   ...                                              ...       ...   ...
# 195  196  월급쟁이 부자로 은퇴하라 :3년 만에 30년 치 연봉을 번 김 과장의 시스템 마련법   327.8700   205
# 196  196      비밀요원 레너드 7 : 인어의 비밀을 찾아라! - 브라운앤프렌즈 미스터리 동화  813.8000   205
# 197  196                  (오은영의) 화해 :상처받은 내면의 나와 마주하는 용기   189.2000   205
# 198  196                           십 년 가게 5 - 한가할 때도 있습니다       NaN   205
# 199  200                                        그리스 로마 신화  219.0000   204
#
# [200 rows x 4 columns]

# %%
#

# %%
# KDC값의 도서 목록이 전부 800번대인것을 확인해 분류를 위해 임의로 800번으로 채우기
busanbest['KDC'] = busanbest['KDC'].fillna('800')

# %%
busanbest
# Out:
#       순위                                               서명       KDC  대출건수
# 0      1                                      욕 좀 하는 이유나      813.7   699
# 1      2                                   아몬드 :손원평 장편소설      813.7   588
# 2      3    오늘의 법정을 열겠습니다 :시민력을 키우는 허승 판사의 법 이야기, 세상 이야기      360.0   517
# 3      4        우리가 인생이라 부르는 것들 :자기 삶의 언어를 찾는 열네 번의 시 강의   811.6209   513
# 4      5                            달러구트 꿈 백화점 :이미예 장편소설      813.7   484
# ..   ...                                              ...       ...   ...
# 195  196  월급쟁이 부자로 은퇴하라 :3년 만에 30년 치 연봉을 번 김 과장의 시스템 마련법     327.87   205
# 196  196      비밀요원 레너드 7 : 인어의 비밀을 찾아라! - 브라운앤프렌즈 미스터리 동화     813.8   205
# 197  196                  (오은영의) 화해 :상처받은 내면의 나와 마주하는 용기      189.2   205
# 198  196                           십 년 가게 5 - 한가할 때도 있습니다       800   205
# 199  200                                        그리스 로마 신화     219.0   204
#
# [200 rows x 4 columns]

# %%
# 남은 결측데이터 제거
busanbest.dropna(inplace=True)
busanbest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   순위      200 non-null    int64
#  1   서명      200 non-null    object
#  2   KDC     200 non-null    object
#  3   대출건수    200 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 7.8+ KB

# %%
busanbest.KDC = busanbest.KDC.astype('str')

# %%
# 인기대출도서목록에서 분야별을 파이그래프로 나타내기
# KDC 시작 숫자 총류(0), 철학(1), 종교(2), 사회과학(3), 자연과학(4), 기술과학(5), 예술(6), 언어(7), 문학(8), 역사(9)로 분류
# 카운드값을 labels에 넣어
busanbest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   순위      200 non-null    int64
#  1   서명      200 non-null    object
#  2   KDC     200 non-null    object
#  3   대출건수    200 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 7.8+ KB

# %%
# 역사도서목록추출
best9 = busanbest[busanbest['KDC'].str.startswith('9',na=True)]
best9.count()
# Out:
# 순위      38
# 서명      38
# KDC     38
# 대출건수    38
# dtype: int64

# %%
best8 = busanbest[busanbest['KDC'].str.startswith('8',na=False)]
best7 = busanbest[busanbest['KDC'].str.startswith('7',na=False)]
best6 = busanbest[busanbest['KDC'].str.startswith('6',na=False)]
best5 = busanbest[busanbest['KDC'].str.startswith('5',na=False)]
best4 = busanbest[busanbest['KDC'].str.startswith('4',na=False)]
best3 = busanbest[busanbest['KDC'].str.startswith('3',na=False)]
best2 = busanbest[busanbest['KDC'].str.startswith('2',na=False)]
best1 = busanbest[busanbest['KDC'].str.startswith('1',na=False)]
best0 = busanbest[busanbest['KDC'].str.startswith('0',na=False)]

# %%
best9 = best9['KDC'].count()
best8 = best8['KDC'].count()
best7 = best7['KDC'].count()
best6 = best6['KDC'].count()
best5 = best5['KDC'].count()
best4 = best4['KDC'].count()
best3 = best3['KDC'].count()
best2 = best2['KDC'].count()
best1 = best1['KDC'].count()
best0 = best0['KDC'].count()

# %%
# KDC 시작 숫자 총류(0), 철학(1), 종교(2), 사회과학(3), 자연과학(4), 기술과학(5), 예술(6), 언어(7), 문학(8), 역사(9)로 분류
count = [best9,best8,best7,best6,best5,best4,best3,best2,best1,best0]
kdc = ['역사','문학','언어','예술','기술과학','자연과학','사회과학','종교','철학','총류']
plt.pie(count, labels=kdc)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
 
## 데이터 준비
colors = ['#9fbcf5','#d9bcad','#bcf593','#87f5b5','#ffba59','#8ce2ff','#c3a6ff','#ffe066','#ff99e5'] ## 색상 ## 색상
labels = ['역사','문학','언어','예술','기술과학','자연과학','사회과학','종교','철학','총류'] ## 라벨 ## 라벨
frequency = [best9,best8,best7,best6,best5,best4,best3,best2,best1,best0] ## 빈도
 
## 데이터 라벨, 빈도수, 색상을 빈도수를 기준으로 정렬해야한다.
labels_frequency = zip(labels,frequency,colors) 
labels_frequency = sorted(labels_frequency,key=lambda x: x[1],reverse=True)
 
sorted_labels = [x[0] for x in labels_frequency] ## 정렬된 라벨
sorted_frequency = [x[1] for x in labels_frequency] ## 정렬된 빈도수
sorted_colors = [x[2] for x in labels_frequency] ## 정렬된 색상
 
fig = plt.figure(figsize=(7,7)) ## 캔버스 생성
fig.set_facecolor('white') ## 캔버스 배경색을 하얀색으로 설정
ax = fig.add_subplot() ## 프레임 생성
 
pie = ax.pie(sorted_frequency, ## 파이차트 출력
       startangle=90, ## 시작점을 90도(degree)로 지정
       counterclock=False, ## 시계방향으로 그려짐
       colors = sorted_colors, ## 색상 지정
       )
 
total = np.sum(frequency) ## 빈도수 합
 
threshold = 5
sum_pct = 0 ## 퍼센티지
count_less_5pct = 0 ## 5%보다 작은 라벨의 개수
spacing = 0.1
# spacing1 = 0.3
for i,l in enumerate(sorted_labels):
    ang1, ang2 = ax.patches[i].theta1, ax.patches[i].theta2 ## 파이의 시작 각도와 끝 각도
    center, r = ax.patches[i].center, ax.patches[i].r ## 파이의 중심 좌표
    
    ## 비율 상한선보다 작은 것들은 계단형태로 만든다.
    if sorted_frequency[i]/total*100 < threshold:
        x = (r/2+spacing*count_less_5pct)*np.cos(np.pi/180*((ang1+ang2)/2)) + center[0] ## 텍스트 x좌표
        y = (r/2+spacing*count_less_5pct)*np.sin(np.pi/180*((ang1+ang2)/2)) + center[1] ## 텍스트 y좌표
        count_less_5pct += 1
    else:
        x = (r/2)*np.cos(np.pi/180*((ang1+ang2)/2)) + center[0] ## 텍스트 x좌표
        y = (r/2)*np.sin(np.pi/180*((ang1+ang2)/2)) + center[1] ## 텍스트 y좌표
        
 
    
    
    ## 퍼센티지 출력
    if i < len(labels) - 1:
        sum_pct += float(f'{sorted_frequency[i]/total*100:.2f}')
        ax.text(x,y,f'{sorted_frequency[i]/total*100:.2f}%',ha='center',va='center',fontsize=12)
        ax.text
#         ax.text(x,y,sorted_labels[i])
    else: ## 마지막 파이 조각은 퍼센티지의 합이 100이 되도록 비율을 조절
        ax.text(x,y,f'{100-sum_pct:.2f}%',ha='center',va='center',fontsize=12)
plt.title('부산 인기 대출 도서',fontsize=15)
plt.legend(pie[0],sorted_labels,bbox_to_anchor=(0.9, 0.45)) ## 범례
plt.savefig('busan.png')
plt.show()
