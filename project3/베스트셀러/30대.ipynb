# %%
import pandas as pd
e_s=pd.read_excel('교보 2021년 상반기 베스트셀러 목록 100위.xlsx')
e_s = e_s.head(100)

# %%
#is_asia = df['continent'] == 'Asia'
age = e_s['연령 1위'] == '30대'
female = e_s['성별 여']

female30 = e_s[age & female]
female30
# Out:
#      순위           ISBN                      도서명  성별 여 성별 남 연령 1위 연령 2위  \
# 4     5  9791165210144            주식투자 무작정 따라하기   49%  51%   30대   40대
# 6     7  9788965422785  해커스 토익 기출 보카 TOEIC VOCA   33%  67%   30대   40대
# 7     8  9788934986652              어떻게 말해줘야 할까   84%  16%   30대   40대
# 10   11  9791190908634       좋은 사람에게만 좋은 사람이면 돼   89%  11%   30대   40대
# 12   13  9788933871553             모래알만 한 진실이라도   83%  17%   30대   40대
# 14   15  9791188331796                    돈의 속성   49%  51%   30대   40대
# 15   16  9791158883591          부자 아빠 가난한 아빠. 1   51%  49%   30대   20대
# 23   24  9791190538206                 홀로서기 심리학   80%  20%   30대   40대
# 26   27  9791160946918                 어린이라는 세계   84%  16%   30대   40대
# 27   28  9788957821176                   월가의 영웅   43%  57%   30대   40대
# 29   30  9791158511906      나의 하루는 4시 30분에 시작된다   94%   6%   30대   40대
# 30   31  9791160022988       주린이도 술술 읽는 친절한 주식책  100%  NaN   30대   NaN
# ...

# %%
e_s.columns=['순위','ISBN','도서명','여','남','1위','2위','저자','출판사','분야']
e_s
# Out:
#      순위           ISBN                        도서명     여    남   1위   2위  \
# 0     1  9791165341909                 달러구트 꿈 백화점  78%   22%  40대  30대
# 1     2  9791160023176  주린이가 가장 알고 싶은 최다질문 TOP 77   59%  41%  40대  30대
# 2     3  9788901246086                 2030 축의 전환  67%   33%  40대  50대
# 3     4  9791164136452                   공정하다는 착각   52%  48%  40대  20대
# 4     5  9791165210144              주식투자 무작정 따라하기   49%  51%  30대  40대
# ..  ...            ...                        ...   ...  ...  ...  ...
# 95   96  9788965423386             해커스 토익 스타트 리스닝  100%  NaN  20대  NaN
# 96   97  9788901248158               유리멘탈을 위한 심리책  78%   22%  20대  40대
# 97   98  9791158741051              심리학을 만나 행복해졌다   63%  37%  50대  30대
# 98   99  9791197410307                    운의 알고리즘   83%  17%  40대  30대
# 99  100  9791155813355                 IT 좀 아는 사람  100%  NaN  30대  NaN
#
#            저자       출판사    분야
# 0         이미예     팩토리나인    소설
# 1         염승환     메이트북스  경제경영
# ...

# %%
e_s.여 = e_s.여.str.split('%').str.get(0)
e_s.남 = e_s.남.str.split('%').str.get(0)
e_s
# Out:
#      순위           ISBN                        도서명    여    남   1위   2위  \
# 0     1  9791165341909                 달러구트 꿈 백화점   78   22  40대  30대
# 1     2  9791160023176  주린이가 가장 알고 싶은 최다질문 TOP 77   59   41  40대  30대
# 2     3  9788901246086                 2030 축의 전환   67   33  40대  50대
# 3     4  9791164136452                   공정하다는 착각   52   48  40대  20대
# 4     5  9791165210144              주식투자 무작정 따라하기   49   51  30대  40대
# ..  ...            ...                        ...  ...  ...  ...  ...
# 95   96  9788965423386             해커스 토익 스타트 리스닝  100  NaN  20대  NaN
# 96   97  9788901248158               유리멘탈을 위한 심리책   78   22  20대  40대
# 97   98  9791158741051              심리학을 만나 행복해졌다   63   37  50대  30대
# 98   99  9791197410307                    운의 알고리즘   83   17  40대  30대
# 99  100  9791155813355                 IT 좀 아는 사람  100  NaN  30대  NaN
#
#            저자       출판사    분야
# 0         이미예     팩토리나인    소설
# 1         염승환     메이트북스  경제경영
# 2      마우로 기옌      리더스북  경제경영
# ...

# %%
e_s['여'] = e_s['여'].fillna(0)
e_s['1위'] = e_s['1위'].fillna(0)
e_s['남'] = e_s['남'].fillna(0)
e_s['2위'] = e_s['2위'].fillna(0)
e_s
# Out:
#      순위           ISBN                        도서명    여   남   1위   2위  \
# 0     1  9791165341909                 달러구트 꿈 백화점   78  22  40대  30대
# 1     2  9791160023176  주린이가 가장 알고 싶은 최다질문 TOP 77   59  41  40대  30대
# 2     3  9788901246086                 2030 축의 전환   67  33  40대  50대
# 3     4  9791164136452                   공정하다는 착각   52  48  40대  20대
# 4     5  9791165210144              주식투자 무작정 따라하기   49  51  30대  40대
# ..  ...            ...                        ...  ...  ..  ...  ...
# 95   96  9788965423386             해커스 토익 스타트 리스닝  100   0  20대    0
# 96   97  9788901248158               유리멘탈을 위한 심리책   78  22  20대  40대
# 97   98  9791158741051              심리학을 만나 행복해졌다   63  37  50대  30대
# 98   99  9791197410307                    운의 알고리즘   83  17  40대  30대
# 99  100  9791155813355                 IT 좀 아는 사람  100   0  30대    0
#
#            저자       출판사    분야
# 0         이미예     팩토리나인    소설
# 1         염승환     메이트북스  경제경영
# 2      마우로 기옌      리더스북  경제경영
# ...

# %%
e_s.남 = e_s.남.astype('int')
e_s.여 = e_s.여.astype('int')
e_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   순위      100 non-null    int64
#  1   ISBN    100 non-null    int64
#  2   도서명     100 non-null    object
#  3   여       100 non-null    int32
#  4   남       100 non-null    int32
#  5   1위      100 non-null    object
#  6   2위      100 non-null    object
#  7   저자      100 non-null    object
#  8   출판사     100 non-null    object
#  9   분야      100 non-null    object
# dtypes: int32(2), int64(2), object(6)
# memory usage: 7.2+ KB

# %%
age30 = e_s['1위'] == '30대'
female = e_s['여'] >= 70
kids = e_s['분야'] != '아동'
kidsc = e_s['분야'] != '아동만화'
teen = e_s['분야'] != '청소년'

# %%
#베스트 셀러 _40대 여성이 제일 많이 보는 책 _ 도서 8개 아동도서가 7
female30 = e_s[age30 & female & kids & kidsc & teen]
#female40 = female40.reset_index(drop =False, inplace = True)
female30
# Out:
#      순위           ISBN                  도서명    여   남   1위   2위         저자  \
# 7     8  9788934986652          어떻게 말해줘야 할까   84  16  30대  40대        오은영
# 10   11  9791190908634   좋은 사람에게만 좋은 사람이면 돼   89  11  30대  40대        김재식
# 12   13  9788933871553         모래알만 한 진실이라도   83  17  30대  40대        박완서
# 23   24  9791190538206             홀로서기 심리학   80  20  30대  40대   라라 E. 필딩
# 26   27  9791160946918             어린이라는 세계   84  16  30대  40대        김소영
# 29   30  9791158511906  나의 하루는 4시 30분에 시작된다   94   6  30대  40대        김유진
# 30   31  9791160022988   주린이도 술술 읽는 친절한 주식책  100   0  30대    0        최정희
# 34   35  9788901243658        기분이 태도가 되지 않게   73  27  30대  40대       레몬심리
# 42   43  9791162541807    뉴욕주민의 진짜 미국식 주식투자  100   0  30대  50대       뉴욕주민
# 47   48  9791191308198           50 홍정욱 에세이   86  14  30대  20대        홍정욱
# 56   57  9791190382267              마음챙김의 시   74  26  30대  40대   류시화 (엮음)
# 62   63  9788965423355        해커스 토익 LC 리스닝   78  22  30대  20대  David Cho
# ...

# %%
#**아동 도서 빌리지 않는다.** 
# 베이비 도서 구매를 하지 않는다 , 도서관에서 빌린다

female30 = e_s[age30 & female ]
#female40 = female40.reset_index(drop =False, inplace = True)
female30.count()
female30
# Out:
#      순위           ISBN                  도서명    여   남   1위   2위         저자  \
# 7     8  9788934986652          어떻게 말해줘야 할까   84  16  30대  40대        오은영
# 10   11  9791190908634   좋은 사람에게만 좋은 사람이면 돼   89  11  30대  40대        김재식
# 12   13  9788933871553         모래알만 한 진실이라도   83  17  30대  40대        박완서
# 23   24  9791190538206             홀로서기 심리학   80  20  30대  40대   라라 E. 필딩
# 26   27  9791160946918             어린이라는 세계   84  16  30대  40대        김소영
# 29   30  9791158511906  나의 하루는 4시 30분에 시작된다   94   6  30대  40대        김유진
# 30   31  9791160022988   주린이도 술술 읽는 친절한 주식책  100   0  30대    0        최정희
# 34   35  9788901243658        기분이 태도가 되지 않게   73  27  30대  40대       레몬심리
# 42   43  9791162541807    뉴욕주민의 진짜 미국식 주식투자  100   0  30대  50대       뉴욕주민
# 47   48  9791191308198           50 홍정욱 에세이   86  14  30대  20대        홍정욱
# 56   57  9791190382267              마음챙김의 시   74  26  30대  40대   류시화 (엮음)
# 62   63  9788965423355        해커스 토익 LC 리스닝   78  22  30대  20대  David Cho
# ...

# %%
import collections
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.countplot(x='분야',data=female30)
# Out:
# <AxesSubplot:xlabel='분야', ylabel='count'>

# %%
# 남자 30대

# %%
age = e_s['1위'] == '30대'
male = e_s['남'] >= 70
kids = e_s['분야'] != '아동'
kidsc = e_s['분야'] != '아동만화'
teen = e_s['분야'] != '청소년'

# %%
male30 = e_s[age & male]
male30
# 40대 남자 2권...
# Out:
#     순위           ISBN          도서명   여   남   1위   2위   저자     출판사    분야
# 64  65  9791162541869  주식 공부 5일 완성  30  70  30대  50대  박민수  비즈니스북스  경제경영

# %%
age = e_s['1위'] == '30대'
sex = e_s['여'] >= 70
kids = e_s['분야'] != '아동'
kidsc = e_s['분야'] != '아동만화'
teen = e_s['분야'] != '청소년'
result = e_s[age & sex & kids & kidsc & teen]
result
# Out:
#      순위           ISBN                  도서명    여   남   1위   2위         저자  \
# 7     8  9788934986652          어떻게 말해줘야 할까   84  16  30대  40대        오은영
# 10   11  9791190908634   좋은 사람에게만 좋은 사람이면 돼   89  11  30대  40대        김재식
# 12   13  9788933871553         모래알만 한 진실이라도   83  17  30대  40대        박완서
# 23   24  9791190538206             홀로서기 심리학   80  20  30대  40대   라라 E. 필딩
# 26   27  9791160946918             어린이라는 세계   84  16  30대  40대        김소영
# 29   30  9791158511906  나의 하루는 4시 30분에 시작된다   94   6  30대  40대        김유진
# 30   31  9791160022988   주린이도 술술 읽는 친절한 주식책  100   0  30대    0        최정희
# 34   35  9788901243658        기분이 태도가 되지 않게   73  27  30대  40대       레몬심리
# 42   43  9791162541807    뉴욕주민의 진짜 미국식 주식투자  100   0  30대  50대       뉴욕주민
# 47   48  9791191308198           50 홍정욱 에세이   86  14  30대  20대        홍정욱
# 56   57  9791190382267              마음챙김의 시   74  26  30대  40대   류시화 (엮음)
# 62   63  9788965423355        해커스 토익 LC 리스닝   78  22  30대  20대  David Cho
# ...

# %%
female30["성별"] = "여"
female30
# Out:
# <ipython-input-15-121003ce9455>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female30["성별"] = "여"
#      순위           ISBN                  도서명    여   남   1위   2위         저자  \
# 7     8  9788934986652          어떻게 말해줘야 할까   84  16  30대  40대        오은영
# 10   11  9791190908634   좋은 사람에게만 좋은 사람이면 돼   89  11  30대  40대        김재식
# 12   13  9788933871553         모래알만 한 진실이라도   83  17  30대  40대        박완서
# 23   24  9791190538206             홀로서기 심리학   80  20  30대  40대   라라 E. 필딩
# 26   27  9791160946918             어린이라는 세계   84  16  30대  40대        김소영
# 29   30  9791158511906  나의 하루는 4시 30분에 시작된다   94   6  30대  40대        김유진
# 30   31  9791160022988   주린이도 술술 읽는 친절한 주식책  100   0  30대    0        최정희
# ...

# %%
male30["성별"] = "남"
male30
# Out:
# <ipython-input-16-97473fb62aae>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male30["성별"] = "남"
#     순위           ISBN          도서명   여   남   1위   2위   저자     출판사    분야 성별
# 64  65  9791162541869  주식 공부 5일 완성  30  70  30대  50대  박민수  비즈니스북스  경제경영  남

# %%
result2 = pd.concat([female30,male30], ignore_index=True)
result2
# Out:
#      순위           ISBN                  도서명    여   남   1위   2위         저자  \
# 0     8  9788934986652          어떻게 말해줘야 할까   84  16  30대  40대        오은영
# 1    11  9791190908634   좋은 사람에게만 좋은 사람이면 돼   89  11  30대  40대        김재식
# 2    13  9788933871553         모래알만 한 진실이라도   83  17  30대  40대        박완서
# 3    24  9791190538206             홀로서기 심리학   80  20  30대  40대   라라 E. 필딩
# 4    27  9791160946918             어린이라는 세계   84  16  30대  40대        김소영
# 5    30  9791158511906  나의 하루는 4시 30분에 시작된다   94   6  30대  40대        김유진
# 6    31  9791160022988   주린이도 술술 읽는 친절한 주식책  100   0  30대    0        최정희
# 7    35  9788901243658        기분이 태도가 되지 않게   73  27  30대  40대       레몬심리
# 8    43  9791162541807    뉴욕주민의 진짜 미국식 주식투자  100   0  30대  50대       뉴욕주민
# 9    48  9791191308198           50 홍정욱 에세이   86  14  30대  20대        홍정욱
# 10   57  9791190382267              마음챙김의 시   74  26  30대  40대   류시화 (엮음)
# 11   63  9788965423355        해커스 토익 LC 리스닝   78  22  30대  20대  David Cho
# ...

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
ax = sns.countplot(x='분야', hue='성별',data=result2,palette=palette)
palette = ['lightpink','lightblue']
# plt.figure(figsize=(20,10))
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().set_facecolor('#f0efed')
ax.set(xlabel=None)
# plt.savefig('bestloan50.png')
plt.title('30대 성별 선호 분야')
plt.savefig('gender30.png')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
palette = ['#e6957a','#a85c32','#9da045','#83a846','#ce974c','#4cabac','#efe6f0','#cedeed']
# plt.figure(figsize=(20,10))
ax = sns.countplot(x='분야',data=e_s[age30],palette=palette)
# plt.figure(figsize=(20,10))
plt.xticks(fontsize=12,rotation=30)
plt.yticks(fontsize=12)
# plt.ylim(0, 20)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().set_facecolor('#f0efed')
ax.set(xlabel=None)
plt.title('30대 베스트셀러 선호 분야')
plt.savefig('bestseller30.png')
plt.show()
