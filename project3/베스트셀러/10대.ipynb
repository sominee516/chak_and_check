# %%
##### 데이터 쓰지 않음!!!!!!!!!!! #####
## 안쓰는 이유 소설분야만 전부 나와 분석이 불가능
# 10대는 소설 분야만 주로 읽어서 데이터 쓰지 않음

import pandas as pd
e_s=pd.read_excel('교보 2021년 상반기 베스트셀러 목록 100위.xlsx')
e_s = e_s.head(100)
age = e_s['연령 1위'] == '10대'
female = e_s['성별 여']

female10 = e_s[age & female]
female10
# Out:
#     순위           ISBN      도서명 성별 여 성별 남 연령 1위 연령 2위        저자   출판사  분야
# 5    6  9788936434267      아몬드  55%  45%   10대   50대       손원평    창비  소설
# 16  17  9788970129815   파친코. 1  75%  25%   10대   40대       이민진  문학사상  소설
# 81  82  9791196814342  요리코를 위해  73%  27%   10대   30대  노리즈키 린타로    모모  소설
# 90  91  9788937461033    인간 실격  72%  28%   10대   40대   다자이 오사무   민음사  소설

# %%
e_s.columns=['순위','ISBN','도서명','여','남','1위','2위','저자','출판사','분야']
e_s
# Out:
#      순위           ISBN                        도서명     여    남   1위   2위  \
# 0     1  9791165341909                 달러구트 꿈 백화점  78%   22%  40대  30대
# 1     2  9791160023176  주린이가 가장 알고 싶은 최다질문 TOP 77   59%  41%  40대  30대
# 2     3  9788901246086                 2030 축의 전환  67%   33%  40대  50대
# 3     4  9791164136452                   공정하다는 착각   52%  48%  40대  20대
# 4     5  9791165210144              주식투자 무작정 따라하기   49%  51%  30대  40대
# ..  ...            ...                        ...   ...  ...  ...  ...
# 95   96  9788965423386             해커스 토익 스타트 리스닝  100%  NaN  20대  NaN
# 96   97  9788901248158               유리멘탈을 위한 심리책  78%   22%  20대  40대
# 97   98  9791158741051              심리학을 만나 행복해졌다   63%  37%  50대  30대
# 98   99  9791197410307                    운의 알고리즘   83%  17%  40대  30대
# 99  100  9791155813355                 IT 좀 아는 사람  100%  NaN  30대  NaN
#
#            저자       출판사    분야
# 0         이미예     팩토리나인    소설
# 1         염승환     메이트북스  경제경영
# 2      마우로 기옌      리더스북  경제경영
# 3      마이클 샌델     와이즈베리    인문
# 4         윤재수        길벗  경제경영
# ..        ...       ...   ...
# 95  David Cho  해커스어학연구소  토익토플
# 96   미즈시마 히로코       갤리온  자기계발
# 97        장원청      미디어숲  자기계발
# 98        정회도   소울소사이어티  자기계발
# 99       닐 메타        윌북  경제경영
#
# [100 rows x 10 columns]

# %%
e_s.여 = e_s.여.str.split('%').str.get(0)
e_s.남 = e_s.남.str.split('%').str.get(0)
e_s
# Out:
#      순위           ISBN                        도서명    여    남   1위   2위  \
# 0     1  9791165341909                 달러구트 꿈 백화점   78   22  40대  30대
# 1     2  9791160023176  주린이가 가장 알고 싶은 최다질문 TOP 77   59   41  40대  30대
# 2     3  9788901246086                 2030 축의 전환   67   33  40대  50대
# 3     4  9791164136452                   공정하다는 착각   52   48  40대  20대
# 4     5  9791165210144              주식투자 무작정 따라하기   49   51  30대  40대
# ..  ...            ...                        ...  ...  ...  ...  ...
# 95   96  9788965423386             해커스 토익 스타트 리스닝  100  NaN  20대  NaN
# 96   97  9788901248158               유리멘탈을 위한 심리책   78   22  20대  40대
# 97   98  9791158741051              심리학을 만나 행복해졌다   63   37  50대  30대
# 98   99  9791197410307                    운의 알고리즘   83   17  40대  30대
# 99  100  9791155813355                 IT 좀 아는 사람  100  NaN  30대  NaN
#
#            저자       출판사    분야
# 0         이미예     팩토리나인    소설
# 1         염승환     메이트북스  경제경영
# 2      마우로 기옌      리더스북  경제경영
# 3      마이클 샌델     와이즈베리    인문
# 4         윤재수        길벗  경제경영
# ..        ...       ...   ...
# 95  David Cho  해커스어학연구소  토익토플
# 96   미즈시마 히로코       갤리온  자기계발
# 97        장원청      미디어숲  자기계발
# 98        정회도   소울소사이어티  자기계발
# 99       닐 메타        윌북  경제경영
#
# [100 rows x 10 columns]

# %%
e_s['여'] = e_s['여'].fillna(0)
e_s['1위'] = e_s['1위'].fillna(0)
e_s['남'] = e_s['남'].fillna(0)
e_s['2위'] = e_s['2위'].fillna(0)
e_s
# Out:
#      순위           ISBN                        도서명    여   남   1위   2위  \
# 0     1  9791165341909                 달러구트 꿈 백화점   78  22  40대  30대
# 1     2  9791160023176  주린이가 가장 알고 싶은 최다질문 TOP 77   59  41  40대  30대
# 2     3  9788901246086                 2030 축의 전환   67  33  40대  50대
# 3     4  9791164136452                   공정하다는 착각   52  48  40대  20대
# 4     5  9791165210144              주식투자 무작정 따라하기   49  51  30대  40대
# ..  ...            ...                        ...  ...  ..  ...  ...
# 95   96  9788965423386             해커스 토익 스타트 리스닝  100   0  20대    0
# 96   97  9788901248158               유리멘탈을 위한 심리책   78  22  20대  40대
# 97   98  9791158741051              심리학을 만나 행복해졌다   63  37  50대  30대
# 98   99  9791197410307                    운의 알고리즘   83  17  40대  30대
# 99  100  9791155813355                 IT 좀 아는 사람  100   0  30대    0
#
#            저자       출판사    분야
# 0         이미예     팩토리나인    소설
# 1         염승환     메이트북스  경제경영
# 2      마우로 기옌      리더스북  경제경영
# 3      마이클 샌델     와이즈베리    인문
# 4         윤재수        길벗  경제경영
# ..        ...       ...   ...
# 95  David Cho  해커스어학연구소  토익토플
# 96   미즈시마 히로코       갤리온  자기계발
# 97        장원청      미디어숲  자기계발
# 98        정회도   소울소사이어티  자기계발
# 99       닐 메타        윌북  경제경영
#
# [100 rows x 10 columns]

# %%
e_s.남 = e_s.남.astype('int')
e_s.여 = e_s.여.astype('int')
e_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   순위      100 non-null    int64
#  1   ISBN    100 non-null    int64
#  2   도서명     100 non-null    object
#  3   여       100 non-null    int32
#  4   남       100 non-null    int32
#  5   1위      100 non-null    object
#  6   2위      100 non-null    object
#  7   저자      100 non-null    object
#  8   출판사     100 non-null    object
#  9   분야      100 non-null    object
# dtypes: int32(2), int64(2), object(6)
# memory usage: 7.2+ KB

# %%
age10 = e_s['1위'] == '10대'
female = e_s['여'] >= 50

# %%
import collections
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.countplot(x='분야',data=female10)
# Out:
# <AxesSubplot:xlabel='분야', ylabel='count'>

# %%
female10["성별"] = "여"
female10
# Out:
# <ipython-input-8-5e4f01476002>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female10["성별"] = "여"
#     순위           ISBN      도서명 성별 여 성별 남 연령 1위 연령 2위        저자   출판사  분야 성별
# 5    6  9788936434267      아몬드  55%  45%   10대   50대       손원평    창비  소설  여
# 16  17  9788970129815   파친코. 1  75%  25%   10대   40대       이민진  문학사상  소설  여
# 81  82  9791196814342  요리코를 위해  73%  27%   10대   30대  노리즈키 린타로    모모  소설  여
# 90  91  9788937461033    인간 실격  72%  28%   10대   40대   다자이 오사무   민음사  소설  여

# %%
age10 = e_s['1위'] == '10대'
male = e_s['남'] >= 50
male10 = e_s[age10 & male]
#female40 = female40.reset_index(drop =False, inplace = True)
male10
# Out:
# Empty DataFrame
# Columns: [순위, ISBN, 도서명, 여, 남, 1위, 2위, 저자, 출판사, 분야]
# Index: []

# %%
male10["성별"] = "남"
male10
# Out:
# Empty DataFrame
# Columns: [순위, ISBN, 도서명, 여, 남, 1위, 2위, 저자, 출판사, 분야, 성별]
# Index: []

# %%
result2 = pd.concat([female10,male10], ignore_index=True)
result2
# Out:
#    순위           ISBN      도서명 성별 여 성별 남 연령 1위 연령 2위        저자   출판사  분야 성별  \
# 0   6  9788936434267      아몬드  55%  45%   10대   50대       손원평    창비  소설  여
# 1  17  9788970129815   파친코. 1  75%  25%   10대   40대       이민진  문학사상  소설  여
# 2  82  9791196814342  요리코를 위해  73%  27%   10대   30대  노리즈키 린타로    모모  소설  여
# 3  91  9788937461033    인간 실격  72%  28%   10대   40대   다자이 오사무   민음사  소설  여
#
#     여   남   1위   2위
# 0 NaN NaN  NaN  NaN
# 1 NaN NaN  NaN  NaN
# 2 NaN NaN  NaN  NaN
# 3 NaN NaN  NaN  NaN

# %%
import collections
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.countplot(x='분야', hue='성별',data=result2)
# Out:
# <AxesSubplot:xlabel='분야', ylabel='count'>

# %%
e_s[age10]
# Out:
#     순위           ISBN      도서명   여   남   1위   2위        저자   출판사  분야
# 5    6  9788936434267      아몬드  55  45  10대  50대       손원평    창비  소설
# 16  17  9788970129815   파친코. 1  75  25  10대  40대       이민진  문학사상  소설
# 81  82  9791196814342  요리코를 위해  73  27  10대  30대  노리즈키 린타로    모모  소설
# 90  91  9788937461033    인간 실격  72  28  10대  40대   다자이 오사무   민음사  소설

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.figure(figsize=(20,10))
sns.countplot(x='분야',data=e_s[age10])
# Out:
# <AxesSubplot:xlabel='분야', ylabel='count'>
