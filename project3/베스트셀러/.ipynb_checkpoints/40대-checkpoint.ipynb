# %%
import pandas as pd
e_s=pd.read_excel('교보 2021년 상반기 베스트셀러 목록 100위.xlsx')
e_s = e_s.head(100)

# %%
#is_asia = df['continent'] == 'Asia'
age40 = e_s['연령 1위'] == '40대'
female = e_s['성별 여']

female40 = e_s[age40 & female]
female40
# Out:
#     순위           ISBN                                   도서명  성별 여 성별 남 연령 1위  \
# 0    1  9791165341909                            달러구트 꿈 백화점  78%   22%   40대
# 1    2  9791160023176             주린이가 가장 알고 싶은 최다질문 TOP 77   59%  41%   40대
# 2    3  9788901246086                            2030 축의 전환  67%   33%   40대
# 3    4  9791164136452                              공정하다는 착각   52%  48%   40대
# 8    9  9788901249599                                 질서 너머   38%  62%   40대
# 9   10  9788959896837                          트렌드 코리아 2021   85%  15%   40대
# 13  14  9791164137527                               흔한남매. 7   85%  15%   40대
# 17  18  9791191056372                                돈의 심리학   45%  55%   40대
# 18  19  9791134882761                            귀멸의 칼날. 23   59%  41%   40대
# 19  20  9791162541968                     마지막 몰입: 나를 넘어서는 힘   50%  50%   40대
# 20  21  9791187993797                   나의 첫 투자 수업. 1: 마인드편  78%   22%   40대
# 22  23  9791130634432                               돈의 시나리오   51%  49%   40대
# 24  25  9791191056556                            미드나잇 라이브러리  78%   22%   40대
# 25  26  9791197037153                        작은 별이지만 빛나고 있어   73%  27%   40대
# 28  29  9791189580575                                  메타버스   57%  43%   40대
# 31  32  9788954672214                               시선으로부터,  100%  NaN   40대
# 32  33  9788965423348                          해커스 토익 RC 리딩  100%  NaN   40대
# 33  34  9788965964230                        어떤 죽음이 삶에게 말했다   81%  19%   40대
# 35  36  9791164137053                      추리 천재 엉덩이 탐정. 10   83%  17%   40대
# 36  37  9791157841110                                 미라클모닝   71%  29%   40대
# 37  38  9788901245713                         위기의 시대, 돈의 미래   29%  71%   40대
# 38  39  9788934972464                                  사피엔스   54%  46%   40대
# 40  41  9791164137176                        흔한남매 별난 방탈출. 1   80%  20%   40대
# 43  44  9788983711892                                  코스모스   55%  45%   40대
# 48  49  9791197037122                            안녕, 소중한 사람  78%   22%   40대
# 49  50  9788925588902                        아들아, 돈 공부해야 한다   73%  27%   40대
# 50  51  9791130635712                     흔한남매 불꽃 튀는 우리말. 1   85%  15%   40대
# 51  52  9788934991366                   빌 게이츠, 기후 재앙을 피하는 법  100%  NaN   40대
# 52  53  9791165382841                      설민석의 한국사 대모험. 16   71%  29%   40대
# 57  58  9791130604626                     이토록 공부가 재미있어지는 순간  78%   22%   40대
# 58  59  9788970127248                                 총 균 쇠   56%  44%   40대
# 59  60  9791159036514                                   데미안   84%  16%   40대
# 60  61  9788932474427                                공간의 미래   47%  53%   40대
# 61  62  9788972756194                           나미야 잡화점의 기적   71%  29%   40대
# 63  64  9791158511982                               멘탈의 연금술  100%  NaN   40대
# 71  72  9788950993153                 마법천자문. 50: 착해져라! 착할 선   84%  16%   40대
# 73  74  9788937834790                              정의란 무엇인가   55%  45%   40대
# 74  75  9791196067694                           12가지 인생의 법칙   39%  61%   40대
# 76  77  9788998274931                             봉제인형 살인사건   69%  31%   40대
# 78  79  9791187119845                          나는 나로 살기로 했다   74%  26%   40대
# 79  80  9791188754366                      상장기업 업종 지도(2021)   73%  27%   40대
# 80  81  9788932473901                     이기적 유전자(40주년 기념판)   52%  48%   40대
# 82  83  9791164137121                       흔한남매의 흔한 호기심. 2  100%  NaN   40대
# 87  88  9791190313131              지적 대화를 위한 넓고 얕은 지식: 제로 편    8%  92%   40대
# 88  89  9791164063581                     이상한 과자 가게 전천당. 10  100%  NaN   40대
# 93  94  9788947546980                               강방천의 관점   49%  51%   40대
# 94  95  9791162371732  EEA: English for Everyday Activities   71%  29%   40대
# 98  99  9791197410307                               운의 알고리즘   83%  17%   40대
#
#    연령 2위                 저자              출판사    분야
# 0    30대                이미예            팩토리나인    소설
# 1    30대                염승환            메이트북스  경제경영
# 2    50대             마우로 기옌             리더스북  경제경영
# 3    20대             마이클 샌델            와이즈베리    인문
# 8    30대             조던 피터슨          웅진지식하우스    인문
# 9    20대                김난도             미래의창  경제경영
# 13   30대          흔한남매 (원작)          미래엔아이세움  아동만화
# 17   30대             모건 하우절            인플루엔셜  경제경영
# 18   30대           고토게 코요하루            학산문화사    만화
# 19   30대                짐 퀵           비즈니스북스  자기계발
# 20   50대                김정환           트러스트북스  경제경영
# 22   50대                김종봉             다산북스  경제경영
# 24   30대             매트 헤이그            인플루엔셜    소설
# 25   30대                 소윤             북로망스   에세이
# 28   30대                김상균           플랜비디자인  경제경영
# 31   50대                정세랑             문학동네    소설
# 32   NaN          David Cho         해커스어학연구소  토익토플
# 33   30대                김범석             흐름출판   에세이
# 35   30대                 트롤          미래엔아이세움    아동
# 36   30대              할 엘로드             한빛비즈  자기계발
# 37   30대              짐 로저스             리더스북  경제경영
# 38   10대             유발 하라리              김영사    인문
# 40   30대          흔한남매 (원작)          미래엔아이세움    아동
# 43   30대              칼 세이건           사이언스북스    과학
# 48   30대                정한경             북로망스   에세이
# 49   30대          정선용(정스토리)          알에이치코리아  경제경영
# 50   30대          흔한남매 (원작)            다산어린이  아동만화
# 51   NaN              빌 게이츠              김영사  정치사회
# 52   30대                설민석             아이휴먼  아동만화
# 57   10대                박성혁             다산북스   청소년
# 58   30대          재레드 다이아몬드             문학사상  역사문화
# 59   20대             헤르만 헤세             더스토리    소설
# 60   50대                유현준            을유문화사    인문
# 61   10대           히가시노 게이고             현대문학    소설
# 63   NaN              보도 섀퍼             토네이도  자기계발
# 71   30대                유대영              아울북  아동만화
# 73   10대             마이클 샌델            와이즈베리    인문
# 74   20대          조던 B. 피터슨              메이븐    인문
# 76   10대              다니엘 콜             북플라자    소설
# 78   20대                김수현             마음의숲   에세이
# 79   50대                박찬일           에프엔미디어  경제경영
# 80   10대            리처드 도킨스            을유문화사    과학
# 82   30대          흔한남매 (원작)          미래엔아이세움  아동만화
# 87   50대                채사장  웨일북(whalebooks)    인문
# 88   NaN           히로시마 레이코             길벗스쿨    아동
# 93   20대                강방천           한국경제신문  경제경영
# 94   30대  Lawrence J. Zwier            웅진컴퍼스   외국어
# 98   30대                정회도          소울소사이어티  자기계발

# %%
e_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   순위      100 non-null    int64
#  1   ISBN    100 non-null    int64
#  2   도서명     100 non-null    object
#  3   성별 여    99 non-null     object
#  4   성별 남    87 non-null     object
#  5   연령 1위   100 non-null    object
#  6   연령 2위   93 non-null     object
#  7   저자      100 non-null    object
#  8   출판사     100 non-null    object
#  9   분야      100 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 7.9+ KB

# %%
# data.columns=['행정구역', '총인구수', '세대수', '세대당인구', '남자','여자', '남여비율']
e_s.columns=['순위','ISBN','도서명','여','남','1위','2위','저자','출판사','분야']
e_s
# Out:
#      순위           ISBN                        도서명     여    남   1위   2위  \
# 0     1  9791165341909                 달러구트 꿈 백화점  78%   22%  40대  30대
# 1     2  9791160023176  주린이가 가장 알고 싶은 최다질문 TOP 77   59%  41%  40대  30대
# 2     3  9788901246086                 2030 축의 전환  67%   33%  40대  50대
# 3     4  9791164136452                   공정하다는 착각   52%  48%  40대  20대
# 4     5  9791165210144              주식투자 무작정 따라하기   49%  51%  30대  40대
# ..  ...            ...                        ...   ...  ...  ...  ...
# 95   96  9788965423386             해커스 토익 스타트 리스닝  100%  NaN  20대  NaN
# 96   97  9788901248158               유리멘탈을 위한 심리책  78%   22%  20대  40대
# 97   98  9791158741051              심리학을 만나 행복해졌다   63%  37%  50대  30대
# 98   99  9791197410307                    운의 알고리즘   83%  17%  40대  30대
# 99  100  9791155813355                 IT 좀 아는 사람  100%  NaN  30대  NaN
#
#            저자       출판사    분야
# 0         이미예     팩토리나인    소설
# 1         염승환     메이트북스  경제경영
# 2      마우로 기옌      리더스북  경제경영
# 3      마이클 샌델     와이즈베리    인문
# 4         윤재수        길벗  경제경영
# ..        ...       ...   ...
# 95  David Cho  해커스어학연구소  토익토플
# 96   미즈시마 히로코       갤리온  자기계발
# 97        장원청      미디어숲  자기계발
# 98        정회도   소울소사이어티  자기계발
# 99       닐 메타        윌북  경제경영
#
# [100 rows x 10 columns]

# %%
# data.행정구역 = data.행정구역.str.split('(').str.get(0)
e_s.여 = e_s.여.str.split('%').str.get(0)
e_s.남 = e_s.남.str.split('%').str.get(0)
e_s
# Out:
#      순위           ISBN                        도서명    여    남   1위   2위  \
# 0     1  9791165341909                 달러구트 꿈 백화점   78   22  40대  30대
# 1     2  9791160023176  주린이가 가장 알고 싶은 최다질문 TOP 77   59   41  40대  30대
# 2     3  9788901246086                 2030 축의 전환   67   33  40대  50대
# 3     4  9791164136452                   공정하다는 착각   52   48  40대  20대
# 4     5  9791165210144              주식투자 무작정 따라하기   49   51  30대  40대
# ..  ...            ...                        ...  ...  ...  ...  ...
# 95   96  9788965423386             해커스 토익 스타트 리스닝  100  NaN  20대  NaN
# 96   97  9788901248158               유리멘탈을 위한 심리책   78   22  20대  40대
# 97   98  9791158741051              심리학을 만나 행복해졌다   63   37  50대  30대
# 98   99  9791197410307                    운의 알고리즘   83   17  40대  30대
# 99  100  9791155813355                 IT 좀 아는 사람  100  NaN  30대  NaN
#
#            저자       출판사    분야
# 0         이미예     팩토리나인    소설
# 1         염승환     메이트북스  경제경영
# 2      마우로 기옌      리더스북  경제경영
# 3      마이클 샌델     와이즈베리    인문
# 4         윤재수        길벗  경제경영
# ..        ...       ...   ...
# 95  David Cho  해커스어학연구소  토익토플
# 96   미즈시마 히로코       갤리온  자기계발
# 97        장원청      미디어숲  자기계발
# 98        정회도   소울소사이어티  자기계발
# 99       닐 메타        윌북  경제경영
#
# [100 rows x 10 columns]

# %%
e_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   순위      100 non-null    int64
#  1   ISBN    100 non-null    int64
#  2   도서명     100 non-null    object
#  3   여       99 non-null     object
#  4   남       87 non-null     object
#  5   1위      100 non-null    object
#  6   2위      93 non-null     object
#  7   저자      100 non-null    object
#  8   출판사     100 non-null    object
#  9   분야      100 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 7.9+ KB

# %%
# For a single column using Pandas: df['DataFrame Column'] = df['DataFrame Column'].fillna(0)
# df.fillna(0)
e_s['여'] = e_s['여'].fillna(0)
e_s['1위'] = e_s['1위'].fillna(0)
e_s['남'] = e_s['남'].fillna(0)
e_s['2위'] = e_s['2위'].fillna(0)
e_s
# Out:
#      순위           ISBN                        도서명    여   남   1위   2위  \
# 0     1  9791165341909                 달러구트 꿈 백화점   78  22  40대  30대
# 1     2  9791160023176  주린이가 가장 알고 싶은 최다질문 TOP 77   59  41  40대  30대
# 2     3  9788901246086                 2030 축의 전환   67  33  40대  50대
# 3     4  9791164136452                   공정하다는 착각   52  48  40대  20대
# 4     5  9791165210144              주식투자 무작정 따라하기   49  51  30대  40대
# ..  ...            ...                        ...  ...  ..  ...  ...
# 95   96  9788965423386             해커스 토익 스타트 리스닝  100   0  20대    0
# 96   97  9788901248158               유리멘탈을 위한 심리책   78  22  20대  40대
# 97   98  9791158741051              심리학을 만나 행복해졌다   63  37  50대  30대
# 98   99  9791197410307                    운의 알고리즘   83  17  40대  30대
# 99  100  9791155813355                 IT 좀 아는 사람  100   0  30대    0
#
#            저자       출판사    분야
# 0         이미예     팩토리나인    소설
# 1         염승환     메이트북스  경제경영
# 2      마우로 기옌      리더스북  경제경영
# 3      마이클 샌델     와이즈베리    인문
# 4         윤재수        길벗  경제경영
# ..        ...       ...   ...
# 95  David Cho  해커스어학연구소  토익토플
# 96   미즈시마 히로코       갤리온  자기계발
# 97        장원청      미디어숲  자기계발
# 98        정회도   소울소사이어티  자기계발
# 99       닐 메타        윌북  경제경영
#
# [100 rows x 10 columns]

# %%
e_s.남 = e_s.남.astype('int')
e_s.여 = e_s.여.astype('int')
e_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   순위      100 non-null    int64
#  1   ISBN    100 non-null    int64
#  2   도서명     100 non-null    object
#  3   여       100 non-null    int32
#  4   남       100 non-null    int32
#  5   1위      100 non-null    object
#  6   2위      100 non-null    object
#  7   저자      100 non-null    object
#  8   출판사     100 non-null    object
#  9   분야      100 non-null    object
# dtypes: int32(2), int64(2), object(6)
# memory usage: 7.2+ KB

# %%
#is_asia = df['continent'] == 'Asia'
age40 = e_s['1위'] == '40대'
female = e_s['여'] >= 70
kids = e_s['분야'] != '아동'
kidsc = e_s['분야'] != '아동만화'
teen = e_s['분야'] != '청소년'

# %%
#베스트 셀러 _40대 여성이 제일 많이 보는 책 _ 도서 8개 아동도서가 7
female40 = e_s[age40 & female & kids & kidsc & teen]
#female40 = female40.reset_index(drop =False, inplace = True)
female40
# Out:
#     순위           ISBN                                   도서명    여   남   1위  \
# 0    1  9791165341909                            달러구트 꿈 백화점   78  22  40대
# 9   10  9788959896837                          트렌드 코리아 2021   85  15  40대
# 20  21  9791187993797                   나의 첫 투자 수업. 1: 마인드편   78  22  40대
# 24  25  9791191056556                            미드나잇 라이브러리   78  22  40대
# 25  26  9791197037153                        작은 별이지만 빛나고 있어   73  27  40대
# 31  32  9788954672214                               시선으로부터,  100   0  40대
# 32  33  9788965423348                          해커스 토익 RC 리딩  100   0  40대
# 33  34  9788965964230                        어떤 죽음이 삶에게 말했다   81  19  40대
# 36  37  9791157841110                                 미라클모닝   71  29  40대
# 48  49  9791197037122                            안녕, 소중한 사람   78  22  40대
# 49  50  9788925588902                        아들아, 돈 공부해야 한다   73  27  40대
# 51  52  9788934991366                   빌 게이츠, 기후 재앙을 피하는 법  100   0  40대
# 59  60  9791159036514                                   데미안   84  16  40대
# 61  62  9788972756194                           나미야 잡화점의 기적   71  29  40대
# 63  64  9791158511982                               멘탈의 연금술  100   0  40대
# 78  79  9791187119845                          나는 나로 살기로 했다   74  26  40대
# 79  80  9791188754366                      상장기업 업종 지도(2021)   73  27  40대
# 94  95  9791162371732  EEA: English for Everyday Activities   71  29  40대
# 98  99  9791197410307                               운의 알고리즘   83  17  40대
#
#      2위                 저자       출판사    분야
# 0   30대                이미예     팩토리나인    소설
# 9   20대                김난도      미래의창  경제경영
# 20  50대                김정환    트러스트북스  경제경영
# 24  30대             매트 헤이그     인플루엔셜    소설
# 25  30대                 소윤      북로망스   에세이
# 31  50대                정세랑      문학동네    소설
# 32    0          David Cho  해커스어학연구소  토익토플
# 33  30대                김범석      흐름출판   에세이
# 36  30대              할 엘로드      한빛비즈  자기계발
# 48  30대                정한경      북로망스   에세이
# 49  30대          정선용(정스토리)   알에이치코리아  경제경영
# 51    0              빌 게이츠       김영사  정치사회
# 59  20대             헤르만 헤세      더스토리    소설
# 61  10대           히가시노 게이고      현대문학    소설
# 63    0              보도 섀퍼      토네이도  자기계발
# 78  20대                김수현      마음의숲   에세이
# 79  50대                박찬일    에프엔미디어  경제경영
# 94  30대  Lawrence J. Zwier     웅진컴퍼스   외국어
# 98  30대                정회도   소울소사이어티  자기계발

# %%
#베스트 셀러 _40대 여성이 제일 많이 보는 책 _ 도서 19권 아동도서가 8권 청소년 1권
female40 = e_s[age40 & female ]
#female40 = female40.reset_index(drop =False, inplace = True)
female40.count()
female40count = female40.shape[0]

# %%
# import collections 
#import matplotlib.pyplot as plt 
#num_firends = [100,40,30,30,30,30,30,30,30,30,54,54,54,54,54,54,54,54,25,3,100,100,100,3,3] 
#friend_counts = collections.Counter(num_firends) 
#print('friends:', friend_counts) 
# 가시화 추가 
#xs = range(101) 
#ys = [friend_counts[x] for x in xs] 
# 파이썬에는 이렇게 List구축을 할 수 있습니다. list comprehension 라고 말합니다. 
# plt.bar(xs,ys) 
# plt.axis([0,101,0,25]) 
# plt.xlabel("# of friends") 
# plt.ylabel("# of people") 
# plt.show()

import collections
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.countplot(x='분야',data=female40)
# Out:
#   File "<ipython-input-32-0aa966d5f469>", line 21
#     sns.countplot(x='분야',data=female40,male40)
#                                            ^
# SyntaxError: positional argument follows keyword argument

# %%
# test40 = female40.plot(kind='bar')
# test40.set_xlabel('분야', fontsize=12) 
# test40.set_ylabel('분야', fontsize=12)
plt.rcParams['font.family'] = 'NanumGothic'
sns.countplot(x='분야',data=female40)
# Out:
# <AxesSubplot:xlabel='분야', ylabel='count'>
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49548 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49444 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50689 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50500 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47564 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50640 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 53664 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51061 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54540 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48156 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54924 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50808 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50612 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50556 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49548 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49444 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50689 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50500 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47564 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50640 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 53664 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51061 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54540 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48156 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 52824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54924 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 52397 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50808 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50612 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50556 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
age40 = e_s['1위'] == '40대'
male = e_s['남'] >= 70
kids = e_s['분야'] != '아동'
kidsc = e_s['분야'] != '아동만화'
teen = e_s['분야'] != '청소년'

# %%
male40 = e_s[age40 & male]
male40
sns.countplot(x='분야',data=male40)
# 40대 남자 2권...
# Out:
# <AxesSubplot:xlabel='분야', ylabel='count'>
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50689 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47928 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50556 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50689 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47928 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50556 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#여자는 아이를 대신해서 도서 구입 많았으나 남섬의 경우는 독서량이 차이가 많이 보이다.

# %%
# 여자 남자 독서 비율 평균 구하기
# mean_df = df['grade'].mean()
femalemean = e_s['여'].mean()
femalemean
# Out:
# 68.69

# %%
age40 = e_s['1위'] == '40대'
male = e_s['남'] >= 70
malemean = e_s[age40 & male]
# malecount = malemean.count()
male40count = malemean.shape[0]

# %%
# import matplotlib.pyplot as plt
# plt.rc('font', family ='Namum')
# plt.rcParams[]= False
# plt.title('40대 남녀 분포')
# plt.barh(range(20),m, label ='남성')
# plt.barh(range(20),m, label ='여성')
# plt.legend()
# plt.show()
# female40count
# male40count
# Out:
# 2

# %%
age30 = e_s['1위'] == '30대'
male = e_s['남'] >= 70
kids = e_s['분야'] != '아동'
kidsc = e_s['분야'] != '아동만화'
teen = e_s['분야'] != '청소년'
male30 = e_s[age30 & male & kids & kidsc & teen]

# %%
male30
# 30대 남자 1권...
# Out:
#     순위           ISBN          도서명   여   남   1위   2위   저자     출판사    분야
# 64  65  9791162541869  주식 공부 5일 완성  30  70  30대  50대  박민수  비즈니스북스  경제경영

# %%
age = e_s['1위'] == '40대'
sex = e_s['여'] >= 70
kids = e_s['분야'] != '아동'
kidsc = e_s['분야'] != '아동만화'
teen = e_s['분야'] != '청소년'
result = e_s[age & sex & kids & kidsc & teen]
result
# 30대 여자 17권
# 30대에서 여성이 17권을 읽을 때 남성은 1권을 읽습니다.
# Out:
#     순위           ISBN                                   도서명    여   남   1위  \
# 0    1  9791165341909                            달러구트 꿈 백화점   78  22  40대
# 9   10  9788959896837                          트렌드 코리아 2021   85  15  40대
# 20  21  9791187993797                   나의 첫 투자 수업. 1: 마인드편   78  22  40대
# 24  25  9791191056556                            미드나잇 라이브러리   78  22  40대
# 25  26  9791197037153                        작은 별이지만 빛나고 있어   73  27  40대
# 31  32  9788954672214                               시선으로부터,  100   0  40대
# 32  33  9788965423348                          해커스 토익 RC 리딩  100   0  40대
# 33  34  9788965964230                        어떤 죽음이 삶에게 말했다   81  19  40대
# 36  37  9791157841110                                 미라클모닝   71  29  40대
# 48  49  9791197037122                            안녕, 소중한 사람   78  22  40대
# 49  50  9788925588902                        아들아, 돈 공부해야 한다   73  27  40대
# 51  52  9788934991366                   빌 게이츠, 기후 재앙을 피하는 법  100   0  40대
# 59  60  9791159036514                                   데미안   84  16  40대
# 61  62  9788972756194                           나미야 잡화점의 기적   71  29  40대
# 63  64  9791158511982                               멘탈의 연금술  100   0  40대
# 78  79  9791187119845                          나는 나로 살기로 했다   74  26  40대
# 79  80  9791188754366                      상장기업 업종 지도(2021)   73  27  40대
# 94  95  9791162371732  EEA: English for Everyday Activities   71  29  40대
# 98  99  9791197410307                               운의 알고리즘   83  17  40대
#
#      2위                 저자       출판사    분야
# 0   30대                이미예     팩토리나인    소설
# 9   20대                김난도      미래의창  경제경영
# 20  50대                김정환    트러스트북스  경제경영
# 24  30대             매트 헤이그     인플루엔셜    소설
# 25  30대                 소윤      북로망스   에세이
# 31  50대                정세랑      문학동네    소설
# 32    0          David Cho  해커스어학연구소  토익토플
# 33  30대                김범석      흐름출판   에세이
# 36  30대              할 엘로드      한빛비즈  자기계발
# 48  30대                정한경      북로망스   에세이
# 49  30대          정선용(정스토리)   알에이치코리아  경제경영
# 51    0              빌 게이츠       김영사  정치사회
# 59  20대             헤르만 헤세      더스토리    소설
# 61  10대           히가시노 게이고      현대문학    소설
# 63    0              보도 섀퍼      토네이도  자기계발
# 78  20대                김수현      마음의숲   에세이
# 79  50대                박찬일    에프엔미디어  경제경영
# 94  30대  Lawrence J. Zwier     웅진컴퍼스   외국어
# 98  30대                정회도   소울소사이어티  자기계발

# %%
# 그래프 그리고 싶다 ..
# 여자 count와 남자 count 합쳐서 그래프 그리고 싶다 ....

# %%
female40["성별"] = "여"
female40
# Out:
# <ipython-input-56-a31d5fbf2190>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female40["성별"] = "여"
#     순위           ISBN                                   도서명    여   남   1위  \
# 0    1  9791165341909                            달러구트 꿈 백화점   78  22  40대
# 9   10  9788959896837                          트렌드 코리아 2021   85  15  40대
# 20  21  9791187993797                   나의 첫 투자 수업. 1: 마인드편   78  22  40대
# 24  25  9791191056556                            미드나잇 라이브러리   78  22  40대
# 25  26  9791197037153                        작은 별이지만 빛나고 있어   73  27  40대
# 31  32  9788954672214                               시선으로부터,  100   0  40대
# 32  33  9788965423348                          해커스 토익 RC 리딩  100   0  40대
# 33  34  9788965964230                        어떤 죽음이 삶에게 말했다   81  19  40대
# 36  37  9791157841110                                 미라클모닝   71  29  40대
# 48  49  9791197037122                            안녕, 소중한 사람   78  22  40대
# 49  50  9788925588902                        아들아, 돈 공부해야 한다   73  27  40대
# 51  52  9788934991366                   빌 게이츠, 기후 재앙을 피하는 법  100   0  40대
# 59  60  9791159036514                                   데미안   84  16  40대
# 61  62  9788972756194                           나미야 잡화점의 기적   71  29  40대
# 63  64  9791158511982                               멘탈의 연금술  100   0  40대
# 78  79  9791187119845                          나는 나로 살기로 했다   74  26  40대
# 79  80  9791188754366                      상장기업 업종 지도(2021)   73  27  40대
# 94  95  9791162371732  EEA: English for Everyday Activities   71  29  40대
# 98  99  9791197410307                               운의 알고리즘   83  17  40대
#
#      2위                 저자       출판사    분야 성별
# 0   30대                이미예     팩토리나인    소설  여
# 9   20대                김난도      미래의창  경제경영  여
# 20  50대                김정환    트러스트북스  경제경영  여
# 24  30대             매트 헤이그     인플루엔셜    소설  여
# 25  30대                 소윤      북로망스   에세이  여
# 31  50대                정세랑      문학동네    소설  여
# 32    0          David Cho  해커스어학연구소  토익토플  여
# 33  30대                김범석      흐름출판   에세이  여
# 36  30대              할 엘로드      한빛비즈  자기계발  여
# 48  30대                정한경      북로망스   에세이  여
# 49  30대          정선용(정스토리)   알에이치코리아  경제경영  여
# 51    0              빌 게이츠       김영사  정치사회  여
# 59  20대             헤르만 헤세      더스토리    소설  여
# 61  10대           히가시노 게이고      현대문학    소설  여
# 63    0              보도 섀퍼      토네이도  자기계발  여
# 78  20대                김수현      마음의숲   에세이  여
# 79  50대                박찬일    에프엔미디어  경제경영  여
# 94  30대  Lawrence J. Zwier     웅진컴퍼스   외국어  여
# 98  30대                정회도   소울소사이어티  자기계발  여

# %%
male40["성별"] = "남"
male40
# Out:
# <ipython-input-57-c0ac1399dacd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male40["성별"] = "남"
#     순위           ISBN                       도서명   여   남   1위   2위     저자  \
# 37  38  9788901245713             위기의 시대, 돈의 미래  29  71  40대  30대  짐 로저스
# 87  88  9791190313131  지적 대화를 위한 넓고 얕은 지식: 제로 편   8  92  40대  50대    채사장
#
#                 출판사    분야 성별
# 37             리더스북  경제경영  남
# 87  웨일북(whalebooks)    인문  남

# %%
result2 = pd.concat([female40,male40], ignore_index=True)
result2
# Out:
#     순위           ISBN                                   도서명    여   남   1위  \
# 0    1  9791165341909                            달러구트 꿈 백화점   78  22  40대
# 1   10  9788959896837                          트렌드 코리아 2021   85  15  40대
# 2   21  9791187993797                   나의 첫 투자 수업. 1: 마인드편   78  22  40대
# 3   25  9791191056556                            미드나잇 라이브러리   78  22  40대
# 4   26  9791197037153                        작은 별이지만 빛나고 있어   73  27  40대
# 5   32  9788954672214                               시선으로부터,  100   0  40대
# 6   33  9788965423348                          해커스 토익 RC 리딩  100   0  40대
# 7   34  9788965964230                        어떤 죽음이 삶에게 말했다   81  19  40대
# 8   37  9791157841110                                 미라클모닝   71  29  40대
# 9   49  9791197037122                            안녕, 소중한 사람   78  22  40대
# 10  50  9788925588902                        아들아, 돈 공부해야 한다   73  27  40대
# 11  52  9788934991366                   빌 게이츠, 기후 재앙을 피하는 법  100   0  40대
# 12  60  9791159036514                                   데미안   84  16  40대
# 13  62  9788972756194                           나미야 잡화점의 기적   71  29  40대
# 14  64  9791158511982                               멘탈의 연금술  100   0  40대
# 15  79  9791187119845                          나는 나로 살기로 했다   74  26  40대
# 16  80  9791188754366                      상장기업 업종 지도(2021)   73  27  40대
# 17  95  9791162371732  EEA: English for Everyday Activities   71  29  40대
# 18  99  9791197410307                               운의 알고리즘   83  17  40대
# 19  38  9788901245713                         위기의 시대, 돈의 미래   29  71  40대
# 20  88  9791190313131              지적 대화를 위한 넓고 얕은 지식: 제로 편    8  92  40대
#
#      2위                 저자              출판사    분야 성별
# 0   30대                이미예            팩토리나인    소설  여
# 1   20대                김난도             미래의창  경제경영  여
# 2   50대                김정환           트러스트북스  경제경영  여
# 3   30대             매트 헤이그            인플루엔셜    소설  여
# 4   30대                 소윤             북로망스   에세이  여
# 5   50대                정세랑             문학동네    소설  여
# 6     0          David Cho         해커스어학연구소  토익토플  여
# 7   30대                김범석             흐름출판   에세이  여
# 8   30대              할 엘로드             한빛비즈  자기계발  여
# 9   30대                정한경             북로망스   에세이  여
# 10  30대          정선용(정스토리)          알에이치코리아  경제경영  여
# 11    0              빌 게이츠              김영사  정치사회  여
# 12  20대             헤르만 헤세             더스토리    소설  여
# 13  10대           히가시노 게이고             현대문학    소설  여
# 14    0              보도 섀퍼             토네이도  자기계발  여
# 15  20대                김수현             마음의숲   에세이  여
# 16  50대                박찬일           에프엔미디어  경제경영  여
# 17  30대  Lawrence J. Zwier            웅진컴퍼스   외국어  여
# 18  30대                정회도          소울소사이어티  자기계발  여
# 19  30대              짐 로저스             리더스북  경제경영  남
# 20  50대                채사장  웨일북(whalebooks)    인문  남

# %%
# import matplotlib.pyplot as plt
# ratio = ['남']
# labels = ['여']

# plt.pie(ratio, labels=labels, autopct='%.1f%%')
# plt.show()
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.countplot(x='분야', hue='성별',data=result2)
# Out:
# <AxesSubplot:xlabel='분야', ylabel='count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(20,10))
sns.countplot(x='분야',data=e_s[age40])
# Out:
# <AxesSubplot:xlabel='분야', ylabel='count'>
